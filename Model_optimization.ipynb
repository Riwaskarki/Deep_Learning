# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
charity_df = application_df.drop(columns=['EIN', 'NAME'])
charity_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
charity_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
application_type_counts=charity_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
cutoff_value = 500
application_types_to_replace = application_type_counts[application_type_counts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    charity_df['APPLICATION_TYPE'] = charity_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
charity_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
charity_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
classification_counts = charity_df['CLASSIFICATION'].value_counts()
classification_counts_greater_than_1 = classification_counts[classification_counts > 1]
classification_counts_greater_than_1
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
cutoff_value = 1800
classifications_to_replace = classification_counts[classification_counts < cutoff_value].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
charity_df = pd.get_dummies(charity_df)
charity_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
X = charity_df.drop(columns=['IS_SUCCESSFUL'])
y = charity_df['IS_SUCCESSFUL']

# %%
# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from tensorflow.keras import regularizers

# Create a function to build the model with optimization techniques
def create_optimized_model():
    model = Sequential()

    # Input layer with L2 regularization and dropout for regularization
    model.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.2))  # Dropout layer for regularization

    # Hidden layers with L2 regularization
    model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.2))
    model.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))  # Adjust if multi-class

    # Compile model with optimized settings
    optimizer = Adam(learning_rate=0.0005)  # Lower learning rate for stability
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
import h5py
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras import regularizers

# Create a function to build the model with optimization techniques
def create_optimized_model():
    model = Sequential()

    # Input layer with L2 regularization and dropout for regularization
    model.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(0.2))  # Dropout layer for regularization

    # Hidden layers with L2 regularization
    model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(0.2))
    model.add(Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))  # Adjust if multi-class

    # Compile model with optimized settings
    optimizer = Adam(learning_rate=0.05)  # Lower learning rate for stability
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
# Define callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
callbacks = [early_stopping, reduce_lr]

# Initialize and train the model
model = create_optimized_model()
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6513 - loss: 0.8228 - val_accuracy: 0.6994 - val_loss: 0.6920 - learning_rate: 0.0500
# Epoch 2/50
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6690 - loss: 0.7217 - val_accuracy: 0.7019 - val_loss: 0.6711 - learning_rate: 0.0500
# Epoch 3/50
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6718 - loss: 0.7278 - val_accuracy: 0.6472 - val_loss: 0.6836 - learning_rate: 0.0500
# Epoch 4/50
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6578 - loss: 0.7127 - val_accuracy: 0.7131 - val_loss: 0.6756 - learning_rate: 0.0500
# Epoch 5/50
# ...

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.layers import BatchNormalization

# Define an optimized neural network model
def create_high_accuracy_model():
    model = Sequential()

    # Input layer with batch normalization, L2 regularization, and dropout
    model.add(Dense(128, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))  # Dropout to reduce overfitting

    # Hidden layers with increased neurons and batch normalization
    model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(Dropout(0.3))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))  # Use 'softmax' if multi-class

    # Compile model with an optimized learning rate
    optimizer = Adam(learning_rate=0.0001)  # Reduced learning rate for improved stability
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
# Callbacks to prevent overfitting and adjust learning rate
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
callbacks = [early_stopping, reduce_lr]

# Initialize and train the optimized model
model = create_high_accuracy_model()
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,          # Allow more epochs for thorough training
    batch_size=64,       # Larger batch size for stability
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5402 - loss: 1.0364 - val_accuracy: 0.6829 - val_loss: 0.8780 - learning_rate: 1.0000e-04
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6099 - loss: 0.9226 - val_accuracy: 0.6943 - val_loss: 0.8356 - learning_rate: 1.0000e-04
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6392 - loss: 0.8747 - val_accuracy: 0.6991 - val_loss: 0.8130 - learning_rate: 1.0000e-04
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6623 - loss: 0.8468 - val_accuracy: 0.7034 - val_loss: 0.7976 - learning_rate: 1.0000e-04
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6868 - loss: 0.8186 - val_accuracy: 0.7115 - val_loss: 0.7852 - learning_rate: 1.0000e-04
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6883 - loss: 0.8052 - val_accuracy: 0.7140 - val_loss: 0.7744 - learning_rate: 1.0000e-04
# Epoch 7/100
# ...

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.layers import BatchNormalization

# Define a deeper and more robust model
def create_advanced_model():
    model = Sequential()

    # Input layer with a higher neuron count, L2 regularization, and dropout
    model.add(Dense(256, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=regularizers.l2(0.002)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))  # Higher dropout to prevent overfitting

    # Additional hidden layers with high neuron counts
    model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.002)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.002)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.002)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    # Final layer before output
    model.add(Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.002)))
    model.add(Dropout(0.3))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))  # Binary classification

    # Compile the model with a very low learning rate for stability
    optimizer = Adam(learning_rate=0.00005)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
# Define updated callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=7, min_lr=1e-7)
callbacks = [early_stopping, reduce_lr]

# Initialize and train the advanced model
model = create_advanced_model()
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=150,         # Increase epochs to allow for full convergence
    batch_size=128,     # Larger batch size for batch stability
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/150
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5238 - loss: 1.7791 - val_accuracy: 0.6411 - val_loss: 1.5796 - learning_rate: 5.0000e-05
# Epoch 2/150
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5516 - loss: 1.6863 - val_accuracy: 0.6554 - val_loss: 1.5259 - learning_rate: 5.0000e-05
# Epoch 3/150
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5784 - loss: 1.6258 - val_accuracy: 0.6560 - val_loss: 1.4918 - learning_rate: 5.0000e-05
# Epoch 4/150
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5991 - loss: 1.5648 - val_accuracy: 0.6681 - val_loss: 1.4623 - learning_rate: 5.0000e-05
# Epoch 5/150
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6121 - loss: 1.5317 - val_accuracy: 0.6682 - val_loss: 1.4386 - learning_rate: 5.0000e-05
# Epoch 6/150
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6239 - loss: 1.4973 - val_accuracy: 0.6692 - val_loss: 1.4182 - learning_rate: 5.0000e-05
# Epoch 7/150
# ...

# %%
# Saving the above model in h5 file.
model.save('AlphabetSoupCharity_Optimization.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Initialize the Sequential model
nn = Sequential()

# Input layer with first hidden layer
nn.add(Dense(units=128, activation="relu", input_dim=108))  # Increased units for more complex feature extraction
nn.add(BatchNormalization())  # Batch normalization for stable training
nn.add(Dropout(0.3))  # Dropout to prevent overfitting

# Second hidden layer
nn.add(Dense(units=64, activation="relu"))
nn.add(BatchNormalization())
nn.add(Dropout(0.3))

# Third hidden layer
nn.add(Dense(units=32, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.001)))
nn.add(BatchNormalization())
nn.add(Dropout(0.2))

# Fourth hidden layer
nn.add(Dense(units=16, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.001)))
nn.add(Dropout(0.2))

# Output layer
nn.add(Dense(units=1, activation="sigmoid"))

# Compile the model with an optimized learning rate
optimizer = Adam(learning_rate=0.00005)  # Fine-tuned learning rate for stable training
nn.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                     │ (None, 128)                 │          13,952 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define updated callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=5, min_lr=1e-6)

# Train the model
history = nn.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=70,
    batch_size=64,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/70
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5859 - loss: 0.8202 - val_accuracy: 0.6813 - val_loss: 0.6930 - learning_rate: 5.0000e-05
# Epoch 2/70
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.6220 - loss: 0.7637 - val_accuracy: 0.7006 - val_loss: 0.6752 - learning_rate: 5.0000e-05
# Epoch 3/70
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6402 - loss: 0.7401 - val_accuracy: 0.7080 - val_loss: 0.6644 - learning_rate: 5.0000e-05
# Epoch 4/70
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6457 - loss: 0.7274 - val_accuracy: 0.7090 - val_loss: 0.6568 - learning_rate: 5.0000e-05
# Epoch 5/70
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6587 - loss: 0.7116 - val_accuracy: 0.7144 - val_loss: 0.6526 - learning_rate: 5.0000e-05
# Epoch 6/70
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6675 - loss: 0.6974 - val_accuracy: 0.7155 - val_loss: 0.6497 - learning_rate: 5.0000e-05
# Epoch 7/70
# ...
